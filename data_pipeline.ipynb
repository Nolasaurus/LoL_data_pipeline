# %%
import json
import pandas as pd

league_id = '008da363-45af-4a07-87d2-f22567e27213'

from get_summoner_ids_from_league_id import get_summoner_ids_from_league_id
from get_puuid_by_summon_id import get_puuid_by_summon_id
from get_match_ids_by_puuid import get_match_ids_by_puuid
from get_match_timeline import get_match_timeline
from extract_events_from_timeline import extract_events_from_timeline

# %% [markdown]
# # Create rate limiter and get initial PUUids list

# %%
import time

class RateLimiter:
    def __init__(self, max_requests, period):
        self.max_requests = max_requests
        self.period = period
        self.timestamps = []

    def __call__(self):
        now = time.time()
        self.timestamps = [ts for ts in self.timestamps if ts > now - self.period]

        if len(self.timestamps) < self.max_requests:
            self.timestamps.append(now)
        else:
            oldest_request = min(self.timestamps)
            time_to_wait = self.period - (now - oldest_request)
            time.sleep(time_to_wait)
            self.timestamps.append(time.time())

rl_sec = RateLimiter(20, 1)  # 20 requests per 1 second
rl_min = RateLimiter(100, 120)  # 100 requests per 2 minutes

puuids = []
while len(puuids) < 20: 
    rl_sec()  # Apply rate limiting
    rl_min()  # Apply rate limiting

    summoner_ids = get_summoner_ids_from_league_id(league_id)
    
    for summoner_id in summoner_ids:
        rl_sec()  # Apply rate limiting
        rl_min()  # Apply rate limiting
        
        puuid = get_puuid_by_summon_id(summoner_id)
        puuids.append(puuid)

        if len(puuids) >= 20:
            break
    
print(f"Total puuids: {len(puuids)}")
print(puuids)


pd.DataFrame(puuids).to_csv('puuids.csv')
# Out:
# Total puuids: 20
# ['rOra4jm75Nj0y4-_7D7MVRfiBlpBXhpSonyI0rwwFacc0uV9fg2HC7PgC_nNJZ1WCXFL_EfTBrDLwQ', 'Cw5DTp0JHNYPKCvhFtw17wdGaFimvHUUckg4Fx8w2ZvYK7v9_mZtKHDOpInEGjGO5-5FZzFna-dDHg', 'ox60Cqe2-_wa_jLEVoy241kruFzWrD12QJd-RkxeBP5Mt3Kx5GA54dhPgfDTVtYnH7XbneQFgNi8aQ', 'RHZ59BUcE3vQxkwW_6x1sDkSXAjD9iR50Exf1nWDYYOzJdtpolEijub4KBwiqxamQYxUCfsRz2Ub9w', 'wwCb2LqGsnZUzOMCfC-YdN4tLb2SuPOwhw6yWPezsU9vG7FKoMGkazxBeWG_ebFYsynU6uQ70fqBuw', 'lnMmSlO27sHd6L0HgrYS5ivq8XMQDocSZytgMXsqMeu0dg3BiGxzfH7DGxAcBpuFpUDFIoDylKtvCg', 'rM1y8szWrtdn5qzlF-EA6S1jGpsZ65OC_4_6eaqmP26I5C8y2G-Z8wyqAc3G6RLCfJ9hTBBkSGMLFA', 'wylRJstyPPKMByoq_c4X59sItxo_Qhje0gXRZfQyl__YAa4O8OsjRhWpaNWTJ_byPdoLhalGzyyf3A', 'aFC0kPZY3mGhs0c-MT5blLeSuKiGzr9E9HJI9xEETp6piIgvNdYzx_xWo8f7emBqSmP_C6chMaVrvg', 'QH2QxpwEEEd0_BMQq1iydfZkVpVhDtCwe7QYeyNwd1vv5BWKJmlv2oYQuo_6phOOBKwB6U4ir6f2zA', '4aoPz1JnVaW0nY9N3rC-TwPR_5OORYX56Gpn2HDwe07bxrnT8yBIa1pof8FgL-eZ8aYGA9hYc8S8nQ', 'vRz9RPnMQ7uwkTVnNBZEF0F2ghwP9T_Xs_3hxKBdVrb4w0RSk3BTmbkGd4K866TivqC0G_9aVKJhwg', 'H6QXkKzG7TgF524kZ0MNrcoMml3eune4IKVJAUY35ohjOaRQLy9sADkuglaW1DioYddX91wMjfBrPg', 'dwHeQMe87Gk51H_Kt_l5liaL4DZzgvKHqq-JKh0nOAQr2NxgCYInHS_0nETXwnJi7bZyneH_2wa9EA', 'DkxQ68jV6rb6hysTEyTCqXVkhUmKENbxANRA_zFWFzIwBHC2SmaRKX0ROqscFWaHgIeOR4W1iZQYgQ', 'lzT0So0sqFsQwqoMaIZEOdUeE7mTv7arTZ3S2fAdLAWkOb3-Hb__sd7HmgkWQuIzVD89R1hvnV_gJw', 'ITZZG7kk0Mas2xl7Jjwn9x8Ag1zl2m-2J700qB-SFsitWWgK8hJaXPIJh-ZPVPrKicy8XXux1fsnQw', 'pSliE-6MJZQZJ1LxGAR7yHdzwV86M9a8Ioa9ag20kL_bkga1Ve6ziEJeGx4XYG8i82Y7Es-_OrBCZA', 'esNmP-koa3RwY93MUS-6P7yYx1YvA3KUB6232zT5SF3WzUD-E1lOqDq-0uwShYT3IlGJ6MIh4piYKw', '86n-VeifcqXCuziCU_3rTLrFHttMOh1wG3hrUtA33NBeYdP4cVH03orXVS0MIUE4yTG4oxaCnLqPrg']

# %% [markdown]
# # Get matchIds from PUUids

# %%
import random
import pandas as pd

# Create dict to hold match timelines
match_tl_dict = {}

# Create list to hold selected match IDs
selected_match_ids_list = []

# Iterate over PUUIDs
for puuid in puuids:
    # Apply rate limiting
    rl_sec()
    rl_min()

    # Get match IDs for each PUUID
    match_ids = get_match_ids_by_puuid(puuid)
    
    # Randomly select 10 (or up to 10) matches
    selected_match_ids = random.sample(match_ids, min(10, len(match_ids)))

    # Add selected match IDs to the list
    selected_match_ids_list.extend(selected_match_ids)

# Convert the list of selected match IDs to a DataFrame and save as CSV
pd.DataFrame(selected_match_ids_list, columns=['match_id']).to_csv('selected_match_ids.csv')
print('match_ids complete')
# Out:
# match_ids complete

# %% [markdown]
# # Get matchtimelines and save as JSON

# %%
import json
import os

# Create the 'match_timeline' folder if it doesn't exist
if not os.path.exists('match_timelines'):
    os.makedirs('match_timelines')

# Get match timelines
for match_id in selected_match_ids_list:
    # Apply rate limiting
    rl_sec()
    rl_min()

    # Get match timeline
    match_timeline = get_match_timeline(match_id)

    # Store the match timeline JSONs
    match_tl_dict[match_id] = match_timeline

    # Save the JSON data to a file inside the 'match_timeline' folder
    with open(os.path.join('match_timelines', f'{match_id}.json'), 'w') as json_file:
        json.dump(match_timeline, json_file)

# %% [markdown]
# # convert to tabular format

# %%
m_tl['info']['frames']
# Out:
# [{'events': [{'realTimestamp': 1609043040247,
#     'timestamp': 0,
#     'type': 'PAUSE_END'}],
#   'participantFrames': {'1': {'championStats': {'abilityPower': 0,
#      'armor': 27,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 602,
#      'healthMax': 602,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 340,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 1,
#     'position': {'x': 560, 'y': 581},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '2': {'championStats': {'abilityPower': 0,
#      'armor': 31,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 540,
#      'healthMax': 540,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 28,
#      'movementSpeed': 345,
#      'power': 300,
#      'powerMax': 300,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 2,
#     'position': {'x': 560, 'y': 361},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '3': {'championStats': {'abilityPower': 0,
#      'armor': 37,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 575,
#      'healthMax': 575,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 335,
#      'power': 100,
#      'powerMax': 100,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 3,
#     'position': {'x': 351, 'y': 293},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '4': {'championStats': {'abilityPower': 0,
#      'armor': 26,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 570,
#      'healthMax': 570,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 325,
#      'power': 280,
#      'powerMax': 280,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 4,
#     'position': {'x': 221, 'y': 471},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '5': {'championStats': {'abilityPower': 0,
#      'armor': 29,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 525,
#      'healthMax': 525,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 330,
#      'power': 350,
#      'powerMax': 350,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 5,
#     'position': {'x': 311, 'y': 649},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '6': {'championStats': {'abilityPower': 0,
#      'armor': 38,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 580,
#      'healthMax': 580,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 345,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 6,
#     'position': {'x': 14486, 'y': 14511},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '7': {'championStats': {'abilityPower': 0,
#      'armor': 36,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 580,
#      'healthMax': 580,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 335,
#      'power': 350,
#      'powerMax': 350,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 7,
#     'position': {'x': 14486, 'y': 14291},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '8': {'championStats': {'abilityPower': 0,
#      'armor': 30,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 490,
#      'healthMax': 490,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 345,
#      'power': 115,
#      'powerMax': 115,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 8,
#     'position': {'x': 14277, 'y': 14223},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '9': {'championStats': {'abilityPower': 0,
#      'armor': 28,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 571,
#      'healthMax': 571,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 335,
#      'power': 348,
#      'powerMax': 348,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 9,
#     'position': {'x': 14147, 'y': 14401},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '10': {'championStats': {'abilityPower': 0,
#      'armor': 47,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 25,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 576,
#      'healthMax': 576,
#      'healthRegen': 0,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 335,
#      'power': 302,
#      'powerMax': 302,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 500,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 10,
#     'position': {'x': 14237, 'y': 14579},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0}},
#   'timestamp': 0},
#  {'events': [{'levelUpType': 'NORMAL',
#     'participantId': 4,
#     'skillSlot': 2,
#     'timestamp': 3625,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 2003,
#     'participantId': 5,
#     'timestamp': 5178,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3858,
#     'participantId': 5,
#     'timestamp': 5575,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 1055,
#     'participantId': 4,
#     'timestamp': 5608,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 5,
#     'timestamp': 6070,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 5,
#     'timestamp': 6433,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 4,
#     'timestamp': 7228,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 4,
#     'timestamp': 8252,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 1055,
#     'participantId': 9,
#     'timestamp': 10728,
#     'type': 'ITEM_PURCHASED'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 8,
#     'skillSlot': 1,
#     'timestamp': 11257,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 2003,
#     'participantId': 9,
#     'timestamp': 11851,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 9,
#     'timestamp': 12049,
#     'type': 'ITEM_PURCHASED'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 9,
#     'skillSlot': 1,
#     'timestamp': 13966,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 7,
#     'skillSlot': 1,
#     'timestamp': 15419,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 1083,
#     'participantId': 8,
#     'timestamp': 16542,
#     'type': 'ITEM_PURCHASED'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 5,
#     'skillSlot': 3,
#     'timestamp': 16773,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 2003,
#     'participantId': 8,
#     'timestamp': 17301,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 8,
#     'timestamp': 17764,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 1035,
#     'participantId': 7,
#     'timestamp': 17995,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 1035,
#     'participantId': 2,
#     'timestamp': 19382,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2031,
#     'participantId': 7,
#     'timestamp': 19878,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 2,
#     'timestamp': 20209,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2031,
#     'participantId': 2,
#     'timestamp': 21001,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 7,
#     'timestamp': 22355,
#     'type': 'ITEM_PURCHASED'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 2,
#     'skillSlot': 3,
#     'timestamp': 23281,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 1054,
#     'participantId': 3,
#     'timestamp': 27543,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3850,
#     'participantId': 10,
#     'timestamp': 32034,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 10,
#     'timestamp': 32761,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 10,
#     'timestamp': 32926,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3364,
#     'participantId': 10,
#     'timestamp': 35238,
#     'type': 'ITEM_PURCHASED'},
#    {'creatorId': 4,
#     'timestamp': 39267,
#     'type': 'WARD_PLACED',
#     'wardType': 'YELLOW_TRINKET'},
#    {'creatorId': 7,
#     'timestamp': 45049,
#     'type': 'WARD_PLACED',
#     'wardType': 'YELLOW_TRINKET'},
#    {'itemId': 1055,
#     'participantId': 6,
#     'timestamp': 48981,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 6,
#     'timestamp': 49741,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 3340,
#     'participantId': 6,
#     'timestamp': 50137,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 1036,
#     'participantId': 1,
#     'timestamp': 50566,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 1,
#     'timestamp': 51722,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 1,
#     'timestamp': 52184,
#     'type': 'ITEM_PURCHASED'},
#    {'itemId': 2003,
#     'participantId': 1,
#     'timestamp': 52449,
#     'type': 'ITEM_PURCHASED'}],
#   'participantFrames': {'1': {'championStats': {'abilityPower': 0,
#      'armor': 33,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 78,
#      'attackSpeed': 103,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 602,
#      'healthMax': 602,
#      'healthRegen': 15,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 697,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 1,
#     'position': {'x': 919, 'y': 5664},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '2': {'championStats': {'abilityPower': 0,
#      'armor': 36,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 75,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 555,
#      'healthMax': 555,
#      'healthRegen': 13,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 28,
#      'movementSpeed': 345,
#      'power': 300,
#      'powerMax': 300,
#      'powerRegen': 16,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 2,
#     'position': {'x': 3411, 'y': 7726},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '3': {'championStats': {'abilityPower': 9,
#      'armor': 37,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 61,
#      'attackSpeed': 110,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 5,
#      'cooldownReduction': 0,
#      'health': 655,
#      'healthMax': 655,
#      'healthRegen': 22,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 0,
#      'powerMax': 100,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 50,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 3,
#     'position': {'x': 2512, 'y': 2132},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '4': {'championStats': {'abilityPower': 0,
#      'armor': 32,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 72,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 650,
#      'healthMax': 650,
#      'healthRegen': 7,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 325,
#      'power': 280,
#      'powerMax': 280,
#      'powerRegen': 13,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 4,
#     'position': {'x': 8229, 'y': 3446},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '5': {'championStats': {'abilityPower': 14,
#      'armor': 29,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 47,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 570,
#      'healthMax': 570,
#      'healthRegen': 15,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 330,
#      'power': 350,
#      'powerMax': 350,
#      'powerRegen': 22,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 20,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 5,
#     'position': {'x': 8200, 'y': 3496},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '6': {'championStats': {'abilityPower': 0,
#      'armor': 38,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 78,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 5,
#      'cooldownReduction': 0,
#      'health': 660,
#      'healthMax': 660,
#      'healthRegen': 6,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 704,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 6,
#     'position': {'x': 7550, 'y': 14037},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '7': {'championStats': {'abilityPower': 0,
#      'armor': 36,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 70,
#      'attackSpeed': 110,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 580,
#      'healthMax': 580,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 350,
#      'powerMax': 350,
#      'powerRegen': 16,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 7,
#     'position': {'x': 11266, 'y': 7193},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '8': {'championStats': {'abilityPower': 0,
#      'armor': 30,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 72,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 490,
#      'healthMax': 490,
#      'healthRegen': 13,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 345,
#      'power': 115,
#      'powerMax': 115,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 8,
#     'position': {'x': 8938, 'y': 8685},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '9': {'championStats': {'abilityPower': 0,
#      'armor': 28,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 79,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 666,
#      'healthMax': 666,
#      'healthRegen': 7,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 335,
#      'power': 348,
#      'powerMax': 348,
#      'powerRegen': 16,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 9,
#     'position': {'x': 11406, 'y': 7104},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0},
#    '10': {'championStats': {'abilityPower': 17,
#      'armor': 53,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 60,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 14,
#      'cooldownReduction': 0,
#      'health': 586,
#      'healthMax': 586,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 302,
#      'powerMax': 302,
#      'powerRegen': 18,
#      'spellVamp': 0},
#     'currentGold': 0,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 20,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 10,
#     'position': {'x': 11523, 'y': 7184},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 500,
#     'xp': 0}},
#   'timestamp': 60011},
#  {'events': [{'levelUpType': 'NORMAL',
#     'participantId': 10,
#     'skillSlot': 3,
#     'timestamp': 71022,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 1,
#     'skillSlot': 1,
#     'timestamp': 99437,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 2, 'participantId': 7, 'timestamp': 104688, 'type': 'LEVEL_UP'},
#    {'creatorId': 5,
#     'timestamp': 105415,
#     'type': 'WARD_PLACED',
#     'wardType': 'YELLOW_TRINKET'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 7,
#     'skillSlot': 3,
#     'timestamp': 106771,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 2, 'participantId': 2, 'timestamp': 107432, 'type': 'LEVEL_UP'},
#    {'creatorId': 8,
#     'timestamp': 108985,
#     'type': 'WARD_PLACED',
#     'wardType': 'YELLOW_TRINKET'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 2,
#     'skillSlot': 1,
#     'timestamp': 109448,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 6,
#     'skillSlot': 1,
#     'timestamp': 109944,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 3,
#     'skillSlot': 1,
#     'timestamp': 110209,
#     'type': 'SKILL_LEVEL_UP'}],
#   'participantFrames': {'1': {'championStats': {'abilityPower': 0,
#      'armor': 33,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 78,
#      'attackSpeed': 103,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 602,
#      'healthMax': 602,
#      'healthRegen': 15,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 32,
#      'movementSpeed': 340,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 77,
#     'damageStats': {'magicDamageDone': 225,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 630,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 4,
#      'totalDamageDone': 855,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 4,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 3,
#     'participantId': 1,
#     'position': {'x': 2509, 'y': 12789},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 577,
#     'xp': 240},
#    '2': {'championStats': {'abilityPower': 0,
#      'armor': 64,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 76,
#      'attackSpeed': 115,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 383,
#      'healthMax': 620,
#      'healthRegen': 46,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 28,
#      'movementSpeed': 345,
#      'power': 333,
#      'powerMax': 346,
#      'powerRegen': 107,
#      'spellVamp': 0},
#     'currentGold': 121,
#     'damageStats': {'magicDamageDone': 573,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 248,
#      'physicalDamageDone': 1684,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 478,
#      'totalDamageDone': 2647,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 726,
#      'trueDamageDone': 390,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 4,
#     'level': 2,
#     'minionsKilled': 0,
#     'participantId': 2,
#     'position': {'x': 2184, 'y': 8434},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 621,
#     'xp': 320},
#    '3': {'championStats': {'abilityPower': 9,
#      'armor': 37,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 61,
#      'attackSpeed': 110,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 5,
#      'cooldownReduction': 0,
#      'health': 655,
#      'healthMax': 655,
#      'healthRegen': 22,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 0,
#      'powerMax': 100,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 85,
#     'damageStats': {'magicDamageDone': 170,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 170,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 1,
#     'participantId': 3,
#     'position': {'x': 6240, 'y': 6651},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 535,
#     'xp': 89},
#    '4': {'championStats': {'abilityPower': 0,
#      'armor': 32,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 72,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 580,
#      'healthMax': 650,
#      'healthRegen': 7,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 325,
#      'power': 280,
#      'powerMax': 280,
#      'powerRegen': 13,
#      'spellVamp': 0},
#     'currentGold': 112,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 1028,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 78,
#      'totalDamageDone': 1028,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 78,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 5,
#     'participantId': 4,
#     'position': {'x': 12265, 'y': 2166},
#     'timeEnemySpentControlled': 17681,
#     'totalGold': 612,
#     'xp': 150},
#    '5': {'championStats': {'abilityPower': 14,
#      'armor': 29,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 47,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 570,
#      'healthMax': 570,
#      'healthRegen': 15,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 330,
#      'power': 350,
#      'powerMax': 350,
#      'powerRegen': 22,
#      'spellVamp': 0},
#     'currentGold': 23,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 0,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 0,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 20,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 5,
#     'position': {'x': 12410, 'y': 2260},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 523,
#     'xp': 150},
#    '6': {'championStats': {'abilityPower': 0,
#      'armor': 38,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 78,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 5,
#      'cooldownReduction': 0,
#      'health': 660,
#      'healthMax': 660,
#      'healthRegen': 6,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 345,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 42,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 212,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 212,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 1,
#     'participantId': 6,
#     'position': {'x': 3032, 'y': 13065},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 542,
#     'xp': 120},
#    '7': {'championStats': {'abilityPower': 0,
#      'armor': 38,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 73,
#      'attackSpeed': 143,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 525,
#      'healthMax': 648,
#      'healthRegen': 18,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 386,
#      'powerMax': 386,
#      'powerRegen': 105,
#      'spellVamp': 0},
#     'currentGold': 121,
#     'damageStats': {'magicDamageDone': 327,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 227,
#      'physicalDamageDone': 1434,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 422,
#      'totalDamageDone': 2152,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 649,
#      'trueDamageDone': 390,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 4,
#     'level': 2,
#     'minionsKilled': 0,
#     'participantId': 7,
#     'position': {'x': 12726, 'y': 6440},
#     'timeEnemySpentControlled': 892,
#     'totalGold': 621,
#     'xp': 320},
#    '8': {'championStats': {'abilityPower': 0,
#      'armor': 30,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 72,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 490,
#      'healthMax': 490,
#      'healthRegen': 13,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 345,
#      'power': 115,
#      'powerMax': 115,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 132,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 2077,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 2077,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 6,
#     'participantId': 8,
#     'position': {'x': 7197, 'y': 6792},
#     'timeEnemySpentControlled': 8933,
#     'totalGold': 632,
#     'xp': 270},
#    '9': {'championStats': {'abilityPower': 0,
#      'armor': 28,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 79,
#      'attackSpeed': 113,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 666,
#      'healthMax': 666,
#      'healthRegen': 7,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 30,
#      'movementSpeed': 335,
#      'power': 313,
#      'powerMax': 348,
#      'powerRegen': 16,
#      'spellVamp': 0},
#     'currentGold': 42,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 947,
#      'physicalDamageDoneToChampions': 78,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 947,
#      'totalDamageDoneToChampions': 78,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 1,
#     'participantId': 9,
#     'position': {'x': 13128, 'y': 3321},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 542,
#     'xp': 135},
#    '10': {'championStats': {'abilityPower': 17,
#      'armor': 53,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 60,
#      'attackSpeed': 100,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 14,
#      'cooldownReduction': 0,
#      'health': 586,
#      'healthMax': 586,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 302,
#      'powerMax': 302,
#      'powerRegen': 18,
#      'spellVamp': 0},
#     'currentGold': 23,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 250,
#      'physicalDamageDoneToChampions': 0,
#      'physicalDamageTaken': 0,
#      'totalDamageDone': 250,
#      'totalDamageDoneToChampions': 0,
#      'totalDamageTaken': 0,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 20,
#     'jungleMinionsKilled': 0,
#     'level': 1,
#     'minionsKilled': 0,
#     'participantId': 10,
#     'position': {'x': 13541, 'y': 2603},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 523,
#     'xp': 75}},
#   'timestamp': 120027},
#  {'events': [{'level': 2,
#     'participantId': 8,
#     'timestamp': 127490,
#     'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 8,
#     'skillSlot': 3,
#     'timestamp': 128415,
#     'type': 'SKILL_LEVEL_UP'},
#    {'creatorId': 0,
#     'timestamp': 129506,
#     'type': 'WARD_PLACED',
#     'wardType': 'UNDEFINED'},
#    {'level': 2, 'participantId': 1, 'timestamp': 131256, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 1,
#     'skillSlot': 3,
#     'timestamp': 132446,
#     'type': 'SKILL_LEVEL_UP'},
#    {'itemId': 2003,
#     'participantId': 10,
#     'timestamp': 140901,
#     'type': 'ITEM_DESTROYED'},
#    {'level': 2, 'participantId': 6, 'timestamp': 143677, 'type': 'LEVEL_UP'},
#    {'itemId': 2003,
#     'participantId': 9,
#     'timestamp': 143942,
#     'type': 'ITEM_DESTROYED'},
#    {'level': 2, 'participantId': 4, 'timestamp': 145197, 'type': 'LEVEL_UP'},
#    {'level': 2, 'participantId': 5, 'timestamp': 145197, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 6,
#     'skillSlot': 3,
#     'timestamp': 146088,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 4,
#     'skillSlot': 1,
#     'timestamp': 146584,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 5,
#     'skillSlot': 1,
#     'timestamp': 147211,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 2, 'participantId': 3, 'timestamp': 149160, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 3,
#     'skillSlot': 3,
#     'timestamp': 151374,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 3, 'participantId': 2, 'timestamp': 153290, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 2,
#     'skillSlot': 2,
#     'timestamp': 155667,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 2, 'participantId': 9, 'timestamp': 157716, 'type': 'LEVEL_UP'},
#    {'level': 3, 'participantId': 8, 'timestamp': 158212, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 9,
#     'skillSlot': 3,
#     'timestamp': 158939,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 2, 'participantId': 10, 'timestamp': 162770, 'type': 'LEVEL_UP'},
#    {'level': 3, 'participantId': 7, 'timestamp': 163892, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 10,
#     'skillSlot': 1,
#     'timestamp': 163926,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 7,
#     'skillSlot': 2,
#     'timestamp': 164982,
#     'type': 'SKILL_LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 8,
#     'skillSlot': 1,
#     'timestamp': 165147,
#     'type': 'SKILL_LEVEL_UP'},
#    {'level': 3, 'participantId': 1, 'timestamp': 172712, 'type': 'LEVEL_UP'},
#    {'levelUpType': 'NORMAL',
#     'participantId': 1,
#     'skillSlot': 2,
#     'timestamp': 173671,
#     'type': 'SKILL_LEVEL_UP'}],
#   'participantFrames': {'1': {'championStats': {'abilityPower': 0,
#      'armor': 39,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 83,
#      'attackSpeed': 107,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 637,
#      'healthMax': 740,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 33,
#      'movementSpeed': 340,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 399,
#     'damageStats': {'magicDamageDone': 1785,
#      'magicDamageDoneToChampions': 270,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 1848,
#      'physicalDamageDoneToChampions': 132,
#      'physicalDamageTaken': 203,
#      'totalDamageDone': 3634,
#      'totalDamageDoneToChampions': 403,
#      'totalDamageTaken': 203,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 3,
#     'minionsKilled': 12,
#     'participantId': 1,
#     'position': {'x': 3188, 'y': 12929},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 899,
#     'xp': 875},
#    '2': {'championStats': {'abilityPower': 0,
#      'armor': 41,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 79,
#      'attackSpeed': 117,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 403,
#      'healthMax': 689,
#      'healthRegen': 16,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 29,
#      'movementSpeed': 345,
#      'power': 348,
#      'powerMax': 395,
#      'powerRegen': 107,
#      'spellVamp': 0},
#     'currentGold': 433,
#     'damageStats': {'magicDamageDone': 2039,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 544,
#      'physicalDamageDone': 3867,
#      'physicalDamageDoneToChampions': 319,
#      'physicalDamageTaken': 1118,
#      'totalDamageDone': 6297,
#      'totalDamageDoneToChampions': 319,
#      'totalDamageTaken': 1662,
#      'trueDamageDone': 390,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 12,
#     'level': 3,
#     'minionsKilled': 0,
#     'participantId': 2,
#     'position': {'x': 7337, 'y': 7766},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 933,
#     'xp': 765},
#    '3': {'championStats': {'abilityPower': 9,
#      'armor': 39,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 63,
#      'attackSpeed': 110,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 5,
#      'cooldownReduction': 0,
#      'health': 541,
#      'healthMax': 719,
#      'healthRegen': 23,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 5,
#      'magicResist': 40,
#      'movementSpeed': 335,
#      'power': 0,
#      'powerMax': 100,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 327,
#     'damageStats': {'magicDamageDone': 1158,
#      'magicDamageDoneToChampions': 12,
#      'magicDamageTaken': 0,
#      'physicalDamageDone': 318,
#      'physicalDamageDoneToChampions': 46,
#      'physicalDamageTaken': 329,
#      'totalDamageDone': 1477,
#      'totalDamageDoneToChampions': 58,
#      'totalDamageTaken': 329,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 2,
#     'minionsKilled': 6,
#     'participantId': 3,
#     'position': {'x': 7470, 'y': 7411},
#     'timeEnemySpentControlled': 957,
#     'totalGold': 787,
#     'xp': 636},
#    '4': {'championStats': {'abilityPower': 0,
#      'armor': 34,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 75,
#      'attackSpeed': 115,
# ...
#     'currentGold': 2366,
#     'damageStats': {'magicDamageDone': 8022,
#      'magicDamageDoneToChampions': 2096,
#      'magicDamageTaken': 3667,
#      'physicalDamageDone': 123268,
#      'physicalDamageDoneToChampions': 18920,
#      'physicalDamageTaken': 7355,
#      'totalDamageDone': 134547,
#      'totalDamageDoneToChampions': 22649,
#      'totalDamageTaken': 12102,
#      'trueDamageDone': 3256,
#      'trueDamageDoneToChampions': 1632,
#      'trueDamageTaken': 1079},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 23,
#     'level': 14,
#     'minionsKilled': 159,
#     'participantId': 8,
#     'position': {'x': 6872, 'y': 1631},
#     'timeEnemySpentControlled': 212036,
#     'totalGold': 12706,
#     'xp': 12398},
#    '9': {'championStats': {'abilityPower': 0,
#      'armor': 51,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 209,
#      'attackSpeed': 213,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1371,
#      'healthMax': 1371,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 33,
#      'movementSpeed': 380,
#      'power': 643,
#      'powerMax': 643,
#      'powerRegen': 27,
#      'spellVamp': 0},
#     'currentGold': 367,
#     'damageStats': {'magicDamageDone': 1935,
#      'magicDamageDoneToChampions': 876,
#      'magicDamageTaken': 2513,
#      'physicalDamageDone': 61510,
#      'physicalDamageDoneToChampions': 8834,
#      'physicalDamageTaken': 7596,
#      'totalDamageDone': 68630,
#      'totalDamageDoneToChampions': 10309,
#      'totalDamageTaken': 10109,
#      'trueDamageDone': 5183,
#      'trueDamageDoneToChampions': 598,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 4,
#     'level': 10,
#     'minionsKilled': 105,
#     'participantId': 9,
#     'position': {'x': 10459, 'y': 10208},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 7167,
#     'xp': 7055},
#    '10': {'championStats': {'abilityPower': 24,
#      'armor': 146,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 83,
#      'attackSpeed': 122,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 49,
#      'cooldownReduction': 0,
#      'health': 0,
#      'healthMax': 1719,
#      'healthRegen': 30,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 93,
#      'movementSpeed': 335,
#      'power': 578,
#      'powerMax': 861,
#      'powerRegen': 42,
#      'spellVamp': 0},
#     'currentGold': 594,
#     'damageStats': {'magicDamageDone': 5929,
#      'magicDamageDoneToChampions': 2138,
#      'magicDamageTaken': 1679,
#      'physicalDamageDone': 4256,
#      'physicalDamageDoneToChampions': 1580,
#      'physicalDamageTaken': 5607,
#      'totalDamageDone': 10186,
#      'totalDamageDoneToChampions': 3719,
#      'totalDamageTaken': 7919,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 633},
#     'goldPerSecond': 30,
#     'jungleMinionsKilled': 0,
#     'level': 10,
#     'minionsKilled': 18,
#     'participantId': 10,
#     'position': {'x': 6856, 'y': 1003},
#     'timeEnemySpentControlled': 51625,
#     'totalGold': 5294,
#     'xp': 6196}},
#   'timestamp': 1200401},
#  {'events': [{'levelUpType': 'NORMAL',
#     'participantId': 5,
#     'skillSlot': 3,
#     'timestamp': 1200566,
#     'type': 'SKILL_LEVEL_UP'},
#    {'gameId': 3720451304,
#     'realTimestamp': 1609044253142,
#     'timestamp': 1212754,
#     'type': 'GAME_END',
#     'winningTeam': 200}],
#   'participantFrames': {'1': {'championStats': {'abilityPower': 101,
#      'armor': 88,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 103,
#      'attackSpeed': 143,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1777,
#      'healthMax': 1777,
#      'healthRegen': 408,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 44,
#      'movementSpeed': 385,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 2474,
#     'damageStats': {'magicDamageDone': 41940,
#      'magicDamageDoneToChampions': 6590,
#      'magicDamageTaken': 490,
#      'physicalDamageDone': 9388,
#      'physicalDamageDoneToChampions': 598,
#      'physicalDamageTaken': 9001,
#      'totalDamageDone': 51432,
#      'totalDamageDoneToChampions': 7267,
#      'totalDamageTaken': 9683,
#      'trueDamageDone': 104,
#      'trueDamageDoneToChampions': 78,
#      'trueDamageTaken': 191},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 12,
#     'minionsKilled': 99,
#     'participantId': 1,
#     'position': {'x': 10036, 'y': 1448},
#     'timeEnemySpentControlled': 11167,
#     'totalGold': 7524,
#     'xp': 9753},
#    '2': {'championStats': {'abilityPower': 0,
#      'armor': 69,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 207,
#      'attackSpeed': 154,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1794,
#      'healthMax': 1794,
#      'healthRegen': 37,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 38,
#      'movementSpeed': 423,
#      'power': 744,
#      'powerMax': 870,
#      'powerRegen': 27,
#      'spellVamp': 0},
#     'currentGold': 366,
#     'damageStats': {'magicDamageDone': 17097,
#      'magicDamageDoneToChampions': 1707,
#      'magicDamageTaken': 1563,
#      'physicalDamageDone': 41489,
#      'physicalDamageDoneToChampions': 3817,
#      'physicalDamageTaken': 12931,
#      'totalDamageDone': 66571,
#      'totalDamageDoneToChampions': 5927,
#      'totalDamageTaken': 15185,
#      'trueDamageDone': 7984,
#      'trueDamageDoneToChampions': 402,
#      'trueDamageTaken': 690},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 56,
#     'level': 11,
#     'minionsKilled': 29,
#     'participantId': 2,
#     'position': {'x': 10315, 'y': 1724},
#     'timeEnemySpentControlled': 62701,
#     'totalGold': 7066,
#     'xp': 7657},
#    '3': {'championStats': {'abilityPower': 71,
#      'armor': 60,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 95,
#      'attackSpeed': 117,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 22,
#      'cooldownReduction': 0,
#      'health': 1501,
#      'healthMax': 1501,
#      'healthRegen': 33,
#      'lifesteal': 0,
#      'magicPen': 18,
#      'magicPenPercent': 10,
#      'magicResist': 49,
#      'movementSpeed': 478,
#      'power': 75,
#      'powerMax': 450,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 1930,
#     'damageStats': {'magicDamageDone': 29479,
#      'magicDamageDoneToChampions': 5317,
#      'magicDamageTaken': 1060,
#      'physicalDamageDone': 8699,
#      'physicalDamageDoneToChampions': 1494,
#      'physicalDamageTaken': 15327,
#      'totalDamageDone': 41647,
#      'totalDamageDoneToChampions': 7641,
#      'totalDamageTaken': 17276,
#      'trueDamageDone': 3469,
#      'trueDamageDoneToChampions': 830,
#      'trueDamageTaken': 888},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 10,
#     'minionsKilled': 86,
#     'participantId': 3,
#     'position': {'x': 394, 'y': 461},
#     'timeEnemySpentControlled': 24941,
#     'totalGold': 5745,
#     'xp': 7156},
#    '4': {'championStats': {'abilityPower': 0,
#      'armor': 58,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 174,
#      'attackSpeed': 237,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1317,
#      'healthMax': 1323,
#      'healthRegen': 15,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 33,
#      'movementSpeed': 370,
#      'power': 411,
#      'powerMax': 527,
#      'powerRegen': 20,
#      'spellVamp': 0},
#     'currentGold': 861,
#     'damageStats': {'magicDamageDone': 724,
#      'magicDamageDoneToChampions': 555,
#      'magicDamageTaken': 1680,
#      'physicalDamageDone': 53496,
#      'physicalDamageDoneToChampions': 10969,
#      'physicalDamageTaken': 9238,
#      'totalDamageDone': 55439,
#      'totalDamageDoneToChampions': 12032,
#      'totalDamageTaken': 11112,
#      'trueDamageDone': 1218,
#      'trueDamageDoneToChampions': 507,
#      'trueDamageTaken': 193},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 10,
#     'minionsKilled': 102,
#     'participantId': 4,
#     'position': {'x': 9971, 'y': 1235},
#     'timeEnemySpentControlled': 468474,
#     'totalGold': 6461,
#     'xp': 7037},
#    '5': {'championStats': {'abilityPower': 61,
#      'armor': 53,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 67,
#      'attackSpeed': 115,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 900,
#      'healthMax': 1374,
#      'healthRegen': 30,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 33,
#      'movementSpeed': 439,
#      'power': 907,
#      'powerMax': 970,
#      'powerRegen': 75,
#      'spellVamp': 0},
#     'currentGold': 341,
#     'damageStats': {'magicDamageDone': 7942,
#      'magicDamageDoneToChampions': 3767,
#      'magicDamageTaken': 1657,
#      'physicalDamageDone': 3863,
#      'physicalDamageDoneToChampions': 1332,
#      'physicalDamageTaken': 10086,
#      'totalDamageDone': 14791,
#      'totalDamageDoneToChampions': 5620,
#      'totalDamageTaken': 12209,
#      'trueDamageDone': 2984,
#      'trueDamageDoneToChampions': 520,
#      'trueDamageTaken': 466},
#     'goldPerSecond': 30,
#     'jungleMinionsKilled': 0,
#     'level': 9,
#     'minionsKilled': 14,
#     'participantId': 5,
#     'position': {'x': 9503, 'y': 1183},
#     'timeEnemySpentControlled': 186163,
#     'totalGold': 5216,
#     'xp': 5603},
#    '6': {'championStats': {'abilityPower': 0,
#      'armor': 69,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 213,
#      'attackSpeed': 124,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 51,
#      'cooldownReduction': 0,
#      'health': 1946,
#      'healthMax': 1946,
#      'healthRegen': 64,
#      'lifesteal': 10,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 77,
#      'movementSpeed': 390,
#      'power': 0,
#      'powerMax': 0,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 377,
#     'damageStats': {'magicDamageDone': 0,
#      'magicDamageDoneToChampions': 0,
#      'magicDamageTaken': 6663,
#      'physicalDamageDone': 67561,
#      'physicalDamageDoneToChampions': 12330,
#      'physicalDamageTaken': 9004,
#      'totalDamageDone': 67561,
#      'totalDamageDoneToChampions': 12330,
#      'totalDamageTaken': 15909,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 241},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 0,
#     'level': 12,
#     'minionsKilled': 127,
#     'participantId': 6,
#     'position': {'x': 6784, 'y': 13202},
#     'timeEnemySpentControlled': 69242,
#     'totalGold': 7427,
#     'xp': 9561},
#    '7': {'championStats': {'abilityPower': 0,
#      'armor': 82,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 165,
#      'attackSpeed': 166,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1913,
#      'healthMax': 1913,
#      'healthRegen': 31,
#      'lifesteal': 7,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 50,
#      'movementSpeed': 478,
#      'power': 788,
#      'powerMax': 788,
#      'powerRegen': 30,
#      'spellVamp': 0},
#     'currentGold': 57,
#     'damageStats': {'magicDamageDone': 13835,
#      'magicDamageDoneToChampions': 765,
#      'magicDamageTaken': 4321,
#      'physicalDamageDone': 60552,
#      'physicalDamageDoneToChampions': 2905,
#      'physicalDamageTaken': 14515,
#      'totalDamageDone': 82006,
#      'totalDamageDoneToChampions': 3870,
#      'totalDamageTaken': 19221,
#      'trueDamageDone': 7618,
#      'trueDamageDoneToChampions': 200,
#      'trueDamageTaken': 384},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 92,
#     'level': 11,
#     'minionsKilled': 16,
#     'participantId': 7,
#     'position': {'x': 14340, 'y': 14391},
#     'timeEnemySpentControlled': 190937,
#     'totalGold': 6940,
#     'xp': 7744},
#    '8': {'championStats': {'abilityPower': 0,
#      'armor': 71,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 251,
#      'attackSpeed': 245,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 2,
#      'healthMax': 1591,
#      'healthRegen': 34,
#      'lifesteal': 22,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 55,
#      'movementSpeed': 390,
#      'power': 24,
#      'powerMax': 305,
#      'powerRegen': 0,
#      'spellVamp': 0},
#     'currentGold': 2392,
#     'damageStats': {'magicDamageDone': 8022,
#      'magicDamageDoneToChampions': 2096,
#      'magicDamageTaken': 3667,
#      'physicalDamageDone': 123268,
#      'physicalDamageDoneToChampions': 18920,
#      'physicalDamageTaken': 7355,
#      'totalDamageDone': 134547,
#      'totalDamageDoneToChampions': 22649,
#      'totalDamageTaken': 12102,
#      'trueDamageDone': 3256,
#      'trueDamageDoneToChampions': 1632,
#      'trueDamageTaken': 1079},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 23,
#     'level': 14,
#     'minionsKilled': 159,
#     'participantId': 8,
#     'position': {'x': 6872, 'y': 1631},
#     'timeEnemySpentControlled': 212036,
#     'totalGold': 12732,
#     'xp': 12398},
#    '9': {'championStats': {'abilityPower': 0,
#      'armor': 51,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 209,
#      'attackSpeed': 213,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 0,
#      'cooldownReduction': 0,
#      'health': 1287,
#      'healthMax': 1371,
#      'healthRegen': 17,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 33,
#      'movementSpeed': 380,
#      'power': 399,
#      'powerMax': 643,
#      'powerRegen': 27,
#      'spellVamp': 0},
#     'currentGold': 393,
#     'damageStats': {'magicDamageDone': 2148,
#      'magicDamageDoneToChampions': 876,
#      'magicDamageTaken': 2513,
#      'physicalDamageDone': 62627,
#      'physicalDamageDoneToChampions': 8834,
#      'physicalDamageTaken': 7692,
#      'totalDamageDone': 69959,
#      'totalDamageDoneToChampions': 10309,
#      'totalDamageTaken': 10205,
#      'trueDamageDone': 5183,
#      'trueDamageDoneToChampions': 598,
#      'trueDamageTaken': 0},
#     'goldPerSecond': 0,
#     'jungleMinionsKilled': 4,
#     'level': 10,
#     'minionsKilled': 105,
#     'participantId': 9,
#     'position': {'x': 10903, 'y': 8664},
#     'timeEnemySpentControlled': 0,
#     'totalGold': 7193,
#     'xp': 7055},
#    '10': {'championStats': {'abilityPower': 24,
#      'armor': 146,
#      'armorPen': 0,
#      'armorPenPercent': 0,
#      'attackDamage': 83,
#      'attackSpeed': 122,
#      'bonusArmorPenPercent': 0,
#      'bonusMagicPenPercent': 0,
#      'ccReduction': 49,
#      'cooldownReduction': 0,
#      'health': 0,
#      'healthMax': 1719,
#      'healthRegen': 30,
#      'lifesteal': 0,
#      'magicPen': 0,
#      'magicPenPercent': 0,
#      'magicResist': 93,
#      'movementSpeed': 335,
#      'power': 578,
#      'powerMax': 861,
#      'powerRegen': 42,
#      'spellVamp': 0},
#     'currentGold': 623,
#     'damageStats': {'magicDamageDone': 5929,
#      'magicDamageDoneToChampions': 2138,
#      'magicDamageTaken': 1679,
#      'physicalDamageDone': 4256,
#      'physicalDamageDoneToChampions': 1580,
#      'physicalDamageTaken': 5607,
#      'totalDamageDone': 10186,
#      'totalDamageDoneToChampions': 3719,
#      'totalDamageTaken': 7919,
#      'trueDamageDone': 0,
#      'trueDamageDoneToChampions': 0,
#      'trueDamageTaken': 633},
#     'goldPerSecond': 30,
#     'jungleMinionsKilled': 0,
#     'level': 10,
#     'minionsKilled': 18,
#     'participantId': 10,
#     'position': {'x': 6856, 'y': 1003},
#     'timeEnemySpentControlled': 51625,
#     'totalGold': 5323,
#     'xp': 6196}},
#   'timestamp': 1212754}]

# %%
# Import necessary libraries
import os
import json
import pandas as pd

# Define function to read JSON file
def load_json(file_path):
    # Open and read the JSON file
    with open(file_path, 'r') as file:
        return json.load(file)

# Define function to process all JSON files in a folder
def extract_tables_from_folder(folder_path):
    # List to store all tables (processed data from each JSON file)
    tables = []

    # Loop over all files in the directory
    for file_name in os.listdir(folder_path):
        # Only process JSON files
        if file_name.endswith(".json"):
            # Construct the full file path
            file_path = os.path.join(folder_path, file_name)
            # Extract the match ID from the file name
            match_id = file_name.split('.')[0]

            # Load the JSON file
            m_tl = load_json(file_path)

            # Extract the events from the match timeline
            events_list = extract_events_from_timeline(m_tl)
            
            # Copy the events list and get the unique event types
            df = events_list.copy()
            event_types = df['type'].unique()

            # Compute the game's real start and end timestamps and the game length
            game_start_real_timestamp = int(events_list['realTimestamp'].iloc[0])
            game_end_real_timestamp = int(events_list['realTimestamp'].iloc[-1])
            game_length_ms = game_end_real_timestamp - game_start_real_timestamp

            # Remove the 'realTimestamp' column from the events list
            events_list.drop(columns='realTimestamp', inplace=True)

            # Prepare a dictionary to store event-specific dataframes
            events_dict = {}

            # Loop over all event types (except the first and last)
            for event_type in event_types[1:-1]:
                # Filter the dataframe for the current event type and drop all-NaN columns
                events_df = df[df['type'] == event_type].copy()
                events_df.dropna(axis=1, how='all', inplace=True)

                # Add a new 'match_id' column at the start of the dataframe
                events_df.insert(0, 'match_id', match_id)
                
                # Add the current event dataframe to the dictionary under the current event type
                events_dict[event_type] = events_df

            # Add the current match's data (events_dict) to the list of all tables
            tables.append(events_dict)

    tables.append(events_dict['game_metadata']='START' 'END' game_start_  game_end_)
    # Return the processed data from all matches
    return tables

# Usage example
folder_path = 'match_timelines'
extracted_tables = tabularize_json_from_folder(folder_path)

# %%
extracted_tables[0]['ITEM_PURCHASED']
# Out:
#             match_id  timestamp            type  itemId  participantId
# 1     NA1_4334085229       4522  ITEM_PURCHASED  3850.0           10.0
# 2     NA1_4334085229       4522  ITEM_PURCHASED  2003.0           10.0
# 3     NA1_4334085229       4522  ITEM_PURCHASED  2003.0           10.0
# 4     NA1_4334085229       5354  ITEM_PURCHASED  3340.0           10.0
# 6     NA1_4334085229       8520  ITEM_PURCHASED  2033.0            1.0
# ...              ...        ...             ...     ...            ...
# 1250  NA1_4334085229    2041894  ITEM_PURCHASED  1026.0            5.0
# 1253  NA1_4334085229    2042259  ITEM_PURCHASED  3100.0            8.0
# 1270  NA1_4334085229    2068353  ITEM_PURCHASED  2140.0            9.0
# 1271  NA1_4334085229    2070030  ITEM_PURCHASED  3082.0            4.0
# 1296  NA1_4334085229    2115488  ITEM_PURCHASED  6333.0            7.0
#
# [222 rows x 5 columns]

# %%
len(extracted_tables)
# Out:
# 160

# %%
from extract_events_from_timeline import extract_events_from_timeline
import json

# Replace 'file_name.json' with the actual name of your JSON file
file_path = 'match_timelines/NA1_3720451304.json'
match_id = file_path.split('/')[-1].split('.')[0]

# Function to read the JSON file
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# Load the JSON file and store it as m_tl
m_tl = load_json(file_path)

events_list = extract_events_from_timeline(m_tl)
df = events_list.copy()
event_types = df['type'].unique()

# Get start and end times
game_start_real_timestamp = int(events_list['realTimestamp'].iloc[0])
game_end_real_timestamp = int(events_list['realTimestamp'].iloc[-1])

game_length_ms = game_end_real_timestamp-game_start_real_timestamp
#print(f"Game Duration: 00:{int(game_length_ms/60000)}:{int((game_length_ms%60000)/1000)}:{int((game_length_ms%6000))}")

# redundant after storing timestamps above
events_list.drop(columns='realTimestamp',inplace=True)

events_dict = {}
# exclude PAUSE_END and GAME_END
for event_type in event_types[1:-1]:
    events_df = df[df['type'] == event_type].copy()
    events_df.dropna(axis=1, how='all', inplace=True)
    events_df.insert(0, 'match_id', match_id) 
    events_dict[event_type] = events_df
# Out:
# NA1_3720451304
# Game Duration: 00:20:12:895

# %% [markdown]
# # connect to postgresql

# %%
from sqlalchemy import text
from sqlalchemy.exc import OperationalError
from sqlalchemy import create_engine, Column, Integer, String, ForeignKey
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship

def read_txt(filename):
    with open(filename, 'r') as file:
        return file.read().strip()

password = read_txt('postgres_pw.txt')
host = 'localhost'
database_name = 'loldb'
port = '5432'
engine = create_engine(f'postgresql://postgres:{password}@{host}:{port}/{database_name}')

# Try connecting and executing a simple query
try:
    with engine.connect() as connection:
        result = connection.execute(text("SELECT 1"))
        print("Successfully connected!")
except OperationalError as e:
    print(f"Connection failed: {e}")

from sqlalchemy import create_engine, MetaData

# Get the metadata of the database
metadata = MetaData()
metadata.reflect(bind=engine)

# List all table names
table_names = metadata.tables.keys()

print("Tables in the database:")
for table_name in table_names:
    print(table_name)
# Out:
# Successfully connected!
# Tables in the database:
# MATCH_TIMELINE

# %% [markdown]
# # Split JSONs into tables and load to postgreSQL

# %%
from sqlalchemy import text
from sqlalchemy.exc import OperationalError

try:
    with engine.connect() as connection:
        result = connection.execute(text('SELECT * FROM "MATCH_TIMELINE"'))
        print("Successfully connected!")

        # Fetch all records and print them
        rows = result.fetchall()

        if not rows:
            print("The table is empty. No records to fetch.")
        else:
            for row in rows:
                print(row)

except OperationalError as e:
    print(f"Connection failed: {e.orig}")
# Out:
# Successfully connected!
# The table is empty. No records to fetch.

# %%
import os
import json
from sqlalchemy import create_engine, Table, Column, Integer, String, JSON, MetaData
from sqlalchemy.sql import insert

# Define the table structure
metadata = MetaData()
match_timeline_table = Table(
    'MATCH_TIMELINE',
    metadata,
    Column('id', Integer, primary_key=True, autoincrement=True),
    Column('match_id', String, nullable=False),
    Column('timeline_json', JSON, nullable=False)
)

# Create the table in the database (if it doesn't exist)
metadata.create_all(engine)

total_rows_added = 0

# Connect to the database
with engine.connect() as connection:

    # Loop through each file in the match_timelines directory
    for filename in os.listdir('match_timelines'):

        # Ensure the file is a JSON file
        if filename.endswith('.json'):
            # Open the file and load the JSON data
            with open(os.path.join('match_timelines', filename), 'r') as json_file:
                match_timeline = json.load(json_file)

            # Create an INSERT statement for the match_timeline
            stmt = insert(match_timeline_table).values(match_id=match_id, timeline_json=match_timeline)

            # Execute the statement and increment the total_rows_added by the number of rows affected
            try:
                result = connection.execute(stmt)
                rows_added = result.rowcount
                total_rows_added += rows_added
                print(f"Rows added: {rows_added}")
            except Exception as e:
                print(f"Error occurred when executing INSERT statement: {e}")

print(f"Total rows added: {total_rows_added}")
# Out:
# Error occurred when executing INSERT statement: (psycopg2.errors.NumericValueOutOfRange) integer out of range
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4334085229", "participants": ["pEzq-TwsSVlh_qVqqKbSP-LcHaCSlPSHzYoksh86q-DzJ3F1-uOXY-VL_v4oKc7WsXzN ... (767365 characters truncated) ... iGxzfH7DGxAcBpuFpUDFIoDylKtvCg"}, {"participantId": 10, "puuid": "lbpYhDIEMOhsFmgtcg8JgiJ3ONencq5fiKJqxWxwE4HCpXK3jnUZV9CInwqsNzwFLE9ztahbpg4zhw"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/9h9h)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_3720451304", "participants": ["q75zZ5UBHxu3CCs2u3ROwRdXVLlqmWWIkHIC30mmFDNsy-QO1rSBs6xg95hRs13_m96e ... (394171 characters truncated) ... "participantId": 10, "position": {"x": 6856, "y": 1003}, "timeEnemySpentControlled": 51625, "totalGold": 5323, "xp": 6196}}, "timestamp": 1212754}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_3999408652", "participants": ["VlpVauZCgnHSZP3EkKVviterCBOIYJaWl_J11wQhRczmOzml7MrtGer6gwwwG17fs1YS ... (785664 characters truncated) ... zYusV5qIySoTRiqy0uFy8zQAhx4JGw"}, {"participantId": 10, "puuid": "yWqMfASSUDnSlUGx8m8xMcZckPUzT-z3dweHaTVOYG_RrfiEo9mdr_suavF7NXxBXV9EVW3xMTB1ng"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4730272790", "participants": ["YugR9P-6kAAo5R_ri5e2wTRi-wm9rtdMu8qjr742ilg2hb2YcLwjYRsCcU-yWHlps0Oq ... (361165 characters truncated) ... 9_mZtKHDOpInEGjGO5-5FZzFna-dDHg"}, {"participantId": 8, "puuid": "c4pEjZ3B_xHDQKXCz4ZooY10kgP5AAtCbqg0MqdXKaEh8tr3Ks37mvfx2Y6zJKZA-aq2VAnAjw5v2g"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4729028871", "participants": ["8R4mrUNHWSUFQsZ8l8k7Y5O5ikqge7k0dCDYfoDN5lZgaKeZgy4LXr5NW55kyV2ldHmX ... (659731 characters truncated) ... D9zoCYkRo0wZp4HzscVTpqX9olJ82Q"}, {"participantId": 10, "puuid": "rOra4jm75Nj0y4-_7D7MVRfiBlpBXhpSonyI0rwwFacc0uV9fg2HC7PgC_nNJZ1WCXFL_EfTBrDLwQ"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4316964052", "participants": ["lnMmSlO27sHd6L0HgrYS5ivq8XMQDocSZytgMXsqMeu0dg3BiGxzfH7DGxAcBpuFpUDF ... (495820 characters truncated) ... i6cDoQIjtR-FMvUiLAqd93AEo4PcQQ"}, {"participantId": 10, "puuid": "JccwRViKxm8aVzKe9QNYYp3uwBE9tWzkh24NpF8uvHl2QPkSgwfxoGxw5Njplh1IdF0vYSZzHa1OUQ"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_
}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4729170350", "participants": ["vV-7DCjAokgXtupsNPKid2hN8oVMtpLSrJzu0U_jnWaq4oWwqFj1JXme_x561tJ8CJnj ... (330130 characters truncated) ... iWyHstOxegs9sfX4UmbE5uRKdOhzjg"}, {"participantId": 10, "puuid": "KJhxjOtYa3fJYVCtBZ953hPCfPKG2GA0gJeOd7knU-GRQXoETcBmT7MfNuBheLwYy7zr7tPl0RL-rQ"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_3721826567", "participants": ["l3y8tNWGwoQvzsPNpoiw0ZQahNA35J7CkIQ5ilta_uB2YwlgDWhTR_q38J7HIOXpkyt2 ... (363950 characters truncated) ... articipantId": 10, "position": {"x": 11983, "y": 11363}, "timeEnemySpentControlled": 92872, "totalGold": 4908, "xp": 6173}}, "timestamp": 1278223}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_3953264651", "participants": ["kerdoHxTleoPG8fJQMnO4HtbJz2KjEkzFT-nsch-1hjJJxfWa4Jc8lp5woJXfWsVMzw6 ... (557364 characters truncated) ... fSXpCC1q3RDTwVx4r3I8Dx4gbQQZLw"}, {"participantId": 10, "puuid": "IdeYtC0fX746FZ37hcN5zgzuJnPQgsABioRkqjEJG3aqvZ2o9pvMTxUsc4wEdF1dNXxnj65drmt_4Q"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4349151815", "participants": ["cYZ-GUnxf9ZUU2UEbqfKJTxL_83DvfQv0v124Mj6byi_TgYkmExJsV7JVGvT8yqiGCzj ... (569830 characters truncated) ... m3SpRL38biE8ecb2OsQuqqMeVtPj6A"}, {"participantId": 10, "puuid": "2FqHTWJLEYMj9p5RZBzMDtug7c4L5HtSR_lJqPgKDE6xR7eK3CZ9wBhjhzIxLaZne-4e4YoHM-Ut1A"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4506957849", "participants": ["Zd_uxuvgCfKJDTMxESD8osmsYiPz5acVf-L7-zOocd2-8MWJe2gDtpsFQanEU3xuAo2a ... (430802 characters truncated) ... ticipantId": 7, "puuid": "BOT"}, {"participantId": 8, "puuid": "BOT"}, {"participantId": 9, "puuid": "BOT"}, {"participantId": 10, "puuid": "BOT"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Error occurred when executing INSERT statement: (psycopg2.errors.InFailedSqlTransaction) current transaction is aborted, commands ignored until end of transaction block
#
# [SQL: INSERT INTO "MATCH_TIMELINE" (match_id, timeline_json) VALUES (%(match_id)s, %(timeline_json)s) RETURNING "MATCH_TIMELINE".id]
# [parameters: {'match_id': 4518725197, 'timeline_json': '{"metadata": {"dataVersion": "2", "matchId": "NA1_4518725197", "participants": ["anuWpXbOrpw8s-pvNDdbAsdjpVspa-ngJ2yLaS782r8CdNshrSL9BpPkIJ0tZpT1OKIs ... (436160 characters truncated) ... ul8L0qOQAB9pQKxr3F7RfpP0qBc-Jg"}, {"participantId": 10, "puuid": "USKG41n4TSgdVbYY4eomIJdqRjf8XL8DvvDnBpIfirMY2sxswIfVS_VVc7RMeZDrk8ZO78vm-8zvvg"}]}}'}]
# (Background on this error at: https://sqlalche.me/e/20/2j85)
# Total rows added: 0

# %%
# import json
# league_id = '008da363-45af-4a07-87d2-f22567e27213'

# summoner_ids = get_summoner_ids_from_league_id(league_id)

# puuid = get_puuid_by_summon_id(summoner_ids[0])

# match_ids = get_match_ids_by_puuid(puuid)

# match_timeline = get_match_timeline(match_ids[0])

# timeline_events = extract_events_from_timeline(match_timeline)
